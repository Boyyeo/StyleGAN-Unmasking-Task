# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/aqeelanwar/MaskTheFace.git

# %%
# %cd /content/MaskTheFace
# !pip install -r requirements.txt

# %%
# !unzip /content/drive/Shareddrives/AIProject/Dataset/ffhq_unmasked.zip -d /content/sample_data

# %%
# %cd /content/MaskTheFace
#import shutil
#shutil.rmtree("/content/sample_data/asia_celebA_test_unmasked_masked")
#shutil.rmtree("/content/sample_data/asia_celebA_test_unmasked")
# Out:
# /content/MaskTheFace

# %%
# !python mask_the_face.py --path '/content/sample_data/test' --mask_type all
# Out:
#  __  __           _ _______ _          ______
# |  \/  |         | |__   __| |        |  ____|
# | \  / | __ _ ___| | _| |  | |__   ___| |__ __ _  ___ ___
# | |\/| |/ _` / __| |/ / |  | '_ \ / _ \  __/ _` |/ __/ _ \
# | |  | | (_| \__ \   <| |  | | | |  __/ | | (_| | (_|  __/
# |_|  |_|\__,_|___/_|\_\_|  |_| |_|\___|_|  \__,_|\___\___|
# -------------------------------------------------------------
# -------------------- Masking image files --------------------
# -------------------------------------------------------------
# 100% 3/3 [00:01<00:00,  2.32it/s]
# -------------------------------------------------------------
# ----------------- Masking image directories -----------------
# -------------------------------------------------------------
# 0it [00:00, ?it/s]
# Processing Done

# %%
# %cd /content/sample_data
# !apt-get install rar
# !rar a "AAFD_test_masked.rar" "/content/sample_data/ffhq_unmasked_masked"

# %%
import shutil
shutil.move("/content/sample_data/AAFD_train_masked.rar","/content/drive/Shareddrives/AIProject/Dataset")
shutil.move("/content/sample_data/AAFD_test_masked.rar","/content/drive/Shareddrives/AIProject/Dataset")

# %%
import os
for i in range(100000,200000):
  print(i)
  os.remove("/content/drive/MyDrive/dataset/celeba/img_align_celeba"+"/"+str(i)+".jpg")

# %%
import os
path = '/content/drive/MyDrive/dataset/celeba_masked'
files = os.listdir(path)


for index, file in enumerate(files):
    filenew = file.split("_")[0]+".jpg"
    print(filenew)
    os.rename(os.path.join(path, file), os.path.join(path, filenew))
